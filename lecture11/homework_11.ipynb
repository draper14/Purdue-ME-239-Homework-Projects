# %% [markdown]
# (lecture11:homework)=
# # Homework 11
#
# + Type your name and email in the "Student details" section below.
# + Develop the code and generate the figures you need to solve the problems using this notebook.
# + For the answers that require a mathematical proof or derivation you can either:
#
#     - Type the answer using the built-in latex capabilities. In this case, simply export the notebook as a pdf and upload it on gradescope; or
#     - You can print the notebook (after you are done with all the code), write your answers by hand, scan, turn your response to a single pdf, and upload on gradescope.
#
# + The total homework points are 100. Please note that the problems are not weighed equally.
#
# ```{note}
# + Please match all the pages corresponding to each of the questions when you submit on gradescope.
# ```

# %% [markdown]
# ## Student details
#
# + **First Name:** Christopher
# + **Last Name:** Draper
# + **Email:** draper14@purdue.edu

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(rc={"figure.dpi":100, 'savefig.dpi':300})
sns.set_context('notebook')
sns.set_style("ticks")
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina', 'svg')
import numpy as np
import scipy.stats as st
# Out:
# /tmp/ipykernel_1116/122018214.py:8: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('retina', 'svg')

# %% [markdown]
# (lecture11:homework:problem1)=
# ## Problem 1 - Calculating expectations for discrete random variables
#
# Consider the Categorical random variable $X \sim \text{Categorical}(0.2, 0.4, 0.4)$ taking three discrete values $1, 2,$ and $3$.
# Find the numerical answer for the following.
# Hint: You can do it by hand or write some code. It is up to you.
#
# + $\mathbf{E}[X] = ?$

# %% [markdown]
# **Answer:** weighted avg - $0.2*1+0.4*2+0.4*3=2.2$.\
# $\mathbf{E}[X] = 2.2$
# <br><br><br><br><br>

# %% [markdown]
# + $\mathbf{E}[X^2] = ?$

# %% [markdown]
# **Answer:**  $0.2*1^2+0.4*2^2+0.4*3^2=5.4$\
# $\mathbf{E}[X^2] = 5.4$
# <br><br><br><br>

# %% [markdown]
# + $\mathbf{V}[X] = ?$

# %% [markdown]
# **Answer:**\
# We know variance is the expectation of the square minus the square of the expectation for a random variable, so $\mathbf{V}[X] = 5.4-2.2^2 = 0.56$
# <br><br><br><br>

# %% [markdown]
# + $\mathbf{E}[e^X] = ?$

# %% [markdown]
# **Answer:** For continuous variables it would be an integral of $e^x$ with respect to x, but this is with discrete random variables so we sum: $0.2e^1+0.4e^2+0.4e^3=11.53$
#
# <br><br><br><br>

# %% [markdown]
# (lecture11:homework:problem2)=
# ## Problem 2 - Calculate the expectation and variance of a continuous random variable
#
# Take an exponential random variable, see [Problem 2 of Homework 10](lecture10:homework:problem2),
# with rate parameter $\lambda$:
#
# $$
# T \sim \text{Exp}(\lambda).
# $$
#
# The PDF of the exponential is:
#
# $$
# p(t) = \lambda e^{-\lambda t},
# $$
#
# for $t\ge 0$ and zero otherwise.
#
# + Prove mathematically that $\mathbf{E}[T] = \lambda^{-1}$. Hint: You need to do the integral $\int_0^\infty tp(t)dt$ using [integration by parts](https://en.wikipedia.org/wiki/Integration_by_parts).

# %% [markdown]
# **Answer:** We know $E[T]=\int_0^\infty tp(t)dt$\
# plug in $p(t)$ and solve by integration by parts:\
# $E[T]=\int_0^\infty t(\lambda e^{-\lambda t})dt$\
# $u=t$,   $dv=\lambda e^{-\lambda t}dt$\
# $du=dt$,   $v=-e^{-λt}$\
# $uv-\int vdu = -te^{-\lambda t}-\int (-e^{-λt})dt$ all evaluated from 0 to infinity\
# $E[t]=0+(-\frac{1}{λ}e^{-\lambda t}]_0^\inf$\
# $E[t]=-(-\frac{1}{\lambda})=\frac{1}{\lambda}$
#
# <br><br><br><br>

# %% [markdown]
# + Prove mathematically that $\mathbf{V}[T] = \lambda^{-2}$. Hint: Use integration by parts to find $\mathbf{E}[T^2]=\int_0^\infty t^2 p(t)dt$ and then use one of the properties of the variance.

# %% [markdown]
# **Answer:** We know $E[T^2]=\int_0^\infty t^2p(t)dt$\
# plug in $p(t)$ and solve by integration by parts:\
# $E[T^2]=\int_0^\infty t^2(\lambda e^{-\lambda t})dt$\
# $u^2=t$,   $dv=\lambda e^{-\lambda t}dt$\
# $du=2tdt$,   $v=-e^{-λt}$\
# $uv-\int vdu = -t^2e^{-\lambda t}-\int (-e^{-λt})2tdt$ all evaluated from 0 to infinity\
# $E[T^2]=0+2\int t(-e^{-λt})dt$\
# We know $E[T]=\int_0^\infty t(\lambda e^{-\lambda t})dt = \frac{1}{\lambda}$ from earlier\
# $E[T^2]=\frac{2}{\lambda}*E[T]$\
# $E[T^2]=\frac{2}{\lambda^2}$
# <br><br><br><br>

# %% [markdown]
# (lecture11:homework:problem3)=
# ## Problem 3 - Properties of expectations
#
# Let $X$ be a random variable with expectation $\mathbf{E}[X] = 3$ and variance $\mathbf{V}[X] = 2$.
# Calculate the following expressions.
#
# + $\mathbf{E}[4X] = ?$

# %% [markdown]
# **Answer:**\
#  $=4E[x]=12$
# <br><br><br><br><br><br><br><br>

# %% [markdown]
# + $\mathbf{E}[X + 2] = ?$

# %% [markdown]
# **Answer:**\
# $=E[x]+2=5$
# <br><br><br><br><br><br><br><br>

# %% [markdown]
# + $\mathbf{E}[3X + 1] = ?$

# %% [markdown]
# **Answer:**\
# $=3E[x]+1=3(3)+1=10$
# <br><br><br><br><br><br><br><br>

# %% [markdown]
# + $\mathbf{V}[5X] = ?$

# %% [markdown]
# **Answer:**\
# $=5^2*V[X]=25*2=50$
# <br><br><br><br><br><br><br><br>

# %% [markdown]
# + $\mathbf{V}[X + 3] = ?$

# %% [markdown]
# **Answer:**\
# $=V[X]=2$
# <br><br><br><br><br><br><br><br>

# %% [markdown]
# + $\mathbf{V}[2X + 1] = ?$

# %% [markdown]
# **Answer:**
# $=2^2*V[X]+0=4(2)=8$
# <br><br><br><br><br><br><br><br>

# %% [markdown]
# + $\mathbf{E}[X^2] = ?$

# %% [markdown]
# **Answer:**
# $V[X]=E[X^2]-(E[X])^2$\
# $E[X^2]=V[X]+(E[X])^2$\
# $E[X^2]=2+3^2=11$
# <br><br><br><br><br><br><br><br>

# %% [markdown]
# Run the following code to convert the notebook to a pdf. Verify that the file path to the notebook is correct.

# %%
from google.colab import drive
drive.mount('/content/drive')
# !apt-get install inkscape texlive texlive-xetex texlive-latex-extra pandoc --quiet
# !pip install pypandoc --quiet
# !jupyter nbconvert --to PDF '/content/drive/MyDrive/Colab Notebooks/Copy of homework_11.ipynb'
